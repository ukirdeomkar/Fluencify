# %% [markdown]
# ### Multilayer Perceptron (MLP) for multi-class softmax classification (Keras Tensorflow)

# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
# from keras.optimizers import SGD
from keras.utils import np_utils
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import train_test_split

np.random.seed(7)

# Load the data
X = np.load('feat.npy')
y = np.load('label.npy').ravel() 

number_of_features = len(X[1]) #This has 23 features
number_of_classes = 3

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0) 

#model
model = Sequential()

model.add(Dense(512, input_dim=number_of_features, activation='relu')) 
model.add(Dropout(0.5))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(number_of_classes, activation='softmax'))
# Out:
# 2022-11-15 10:07:53.879889: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               12288
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 3)                 1539
#
# ...
# Total params: 276,483
# Trainable params: 276,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = 'rmsprop'
adam = 'adam'
model.compile(loss='categorical_crossentropy',
              optimizer= rmsprop,
              metrics=['accuracy'])

y_train = keras.utils.np_utils.to_categorical(y_train-1, num_classes= number_of_classes) 
y_test = keras.utils.np_utils.to_categorical(y_test-1, num_classes= number_of_classes)

# %% [markdown]
# # Epoch-300 , batch_size = 64

# %%
model.fit(X_train, y_train, epochs=300, batch_size=64) #batch 32, 64, 128, 256, 512
score, acc = model.evaluate(X_test, y_test, batch_size=64)
# Out:
# Epoch 1/300
# 16/16 [==============================] - 1s 6ms/step - loss: 27.6058 - accuracy: 0.4006
# Epoch 2/300
# 16/16 [==============================] - 0s 6ms/step - loss: 11.1179 - accuracy: 0.4538
# Epoch 3/300
# 16/16 [==============================] - 0s 7ms/step - loss: 6.9264 - accuracy: 0.5040
# Epoch 4/300
# 16/16 [==============================] - 0s 6ms/step - loss: 4.5043 - accuracy: 0.5231
# Epoch 5/300
# 16/16 [==============================] - 0s 6ms/step - loss: 2.7618 - accuracy: 0.5552
# Epoch 6/300
# 16/16 [==============================] - 0s 13ms/step - loss: 1.8427 - accuracy: 0.5793
# Epoch 7/300
# 16/16 [==============================] - 0s 9ms/step - loss: 1.3568 - accuracy: 0.5863
# Epoch 8/300
# 16/16 [==============================] - 0s 8ms/step - loss: 1.2179 - accuracy: 0.5873
# Epoch 9/300
# 16/16 [==============================] - 0s 8ms/step - loss: 1.0035 - accuracy: 0.6285
# Epoch 10/300
# ...

# %%
print ('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Test score: 0.3853221833705902
# Test accuracy: 0.9415887594223022

# %%
import pickle
filename = 'mlp/mlp_300_64.sav'
pickle.dump(model, open(filename, 'wb'))
# Out:
# 2022-11-15 10:08:29.164696: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ram://b5b09351-2994-4adf-a814-ca3661db8658/assets

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(X_test)
print(result)
# Out:
# [[0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [8.6404628e-01 1.3595240e-01 1.2988644e-06]
#  [0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  ...
#  [9.8610538e-01 1.3894674e-02 1.9644220e-11]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [5.7721678e-23 1.0000000e+00 2.2713532e-33]]

# %% [markdown]
# # Epochs = 300  , batch_size=128

# %%
model.fit(X_train, y_train, epochs=300, batch_size=128) #batch 32, 64, 128, 256, 512
score, acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9578
# Epoch 2/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0696 - accuracy: 0.9709
# Epoch 3/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1055 - accuracy: 0.9578
# Epoch 4/300
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1140 - accuracy: 0.9508
# Epoch 5/300
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1120 - accuracy: 0.9528
# Epoch 6/300
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0978 - accuracy: 0.9639
# Epoch 7/300
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0847 - accuracy: 0.9669
# Epoch 8/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1110 - accuracy: 0.9649
# Epoch 9/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0639 - accuracy: 0.9669
# Epoch 10/300
# ...

# %%
print ('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Test score: 0.6060696840286255
# Test accuracy: 0.9322429895401001

# %%
import pickle
filename = 'mlp/mlp_300_128.sav'
pickle.dump(model, open(filename, 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://c744c668-17d1-4484-a63a-4d2394a99b9c/assets

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(X_test)
print(result)
# Out:
# [[0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [9.5400739e-01 4.5992550e-02 2.1836108e-08]
#  [0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  ...
#  [9.9609560e-01 3.9043969e-03 3.7743090e-17]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [6.3941390e-36 1.0000000e+00 0.0000000e+00]]

# %% [markdown]
# # Epochs = 300 , batch_size = 32

# %%
model.fit(X_train, y_train, epochs=300, batch_size=32) #batch 32, 64, 128, 256, 512
score, acc = model.evaluate(X_test, y_test, batch_size=32)
# Out:
# Epoch 1/300
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0985 - accuracy: 0.9689
# Epoch 2/300
# 32/32 [==============================] - 0s 7ms/step - loss: 0.1191 - accuracy: 0.9629
# Epoch 3/300
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0759 - accuracy: 0.9719
# Epoch 4/300
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9588
# Epoch 5/300
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1332 - accuracy: 0.9608
# Epoch 6/300
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1007 - accuracy: 0.9598
# Epoch 7/300
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1294 - accuracy: 0.9568
# Epoch 8/300
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.9739
# Epoch 9/300
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9649
# Epoch 10/300
# ...

# %%
print ('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Test score: 0.8866744637489319
# Test accuracy: 0.9182242751121521

# %%
model.evaluate(X_test, y_test, batch_size=256)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8867 - accuracy: 0.9182
# [0.8866744637489319, 0.9182242751121521]

# %%
import pickle
filename = 'mlp/mlp_300_32.sav'
pickle.dump(model, open(filename, 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://a5e969f2-424e-42bc-b569-9947e68887f3/assets

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.predict(X_test)
print(result)
# Out:
# [[0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [9.9999452e-01 5.5402365e-06 9.0014647e-20]
#  [0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  ...
#  [9.9772447e-01 2.2754981e-03 2.2433949e-15]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00]]

# %% [markdown]
# # Model Testing

# %%
import pickle 
model_test = pickle.load(open('mlp/mlp_300_32.sav', 'rb'))

# %%
import glob
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
import soundfile as sf
import numpy as np 

##Return audio features 
def feature_extraction(file_name):
    #X, sample_rate = sf.read(file_name, dtype='float32')
    X , sample_rate = librosa.load(file_name, sr=None) 
    if X.ndim > 1:
        X = X[:,0]
    X = X.T
    
    ## stFourier Transform
    stft = np.abs(librosa.stft(X))
            
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=20).T, axis=0) 
    rmse = np.mean(librosa.feature.rms(y=X).T, axis=0) 
    spectral_flux = np.mean(librosa.onset.onset_strength(y=X, sr=sample_rate).T, axis=0) 
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=X).T, axis=0)
    
    #mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0) #Returns 128 values
    #chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0) #Returns 12 values
    #contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0) #Returns 7 values
    #tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T, axis=0)
    
    ##Return computed audio features
    return mfccs, rmse, spectral_flux, zcr

# %%
# feature_predict = feature_extraction(file_path)

# %%
predict_path = 'audio-data/002 - Intermediate /Avalinguo - Alan and Eduardo segment 30 - E.mp3'
n_mfccs = 20 
number_of_features = 3 + n_mfccs
features = np.empty((0,number_of_features))
mfccs, rmse, spectral_flux, zcr = feature_extraction(predict_path)
extracted_features = np.hstack([mfccs, rmse, spectral_flux, zcr])
features_predict = np.vstack([features, extracted_features])
result = model_test.predict(features_predict)

# %%
result[0]
# Out:
# array([1.6808353e-07, 9.9999964e-01, 2.8777660e-07], dtype=float32)

# %%
i = np.argmax(result[0])
if(i==0):
    print('LOW')
elif(i==1):
    print('INTERMEDIATE')
else:
    print('HIGH')
# Out:
# INTERMEDIATE

# %% [markdown]
# # Live Audio Capture and Classification

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv
import numpy as np
from pydub import AudioSegment

  
freq = 44100
  
duration = 10
  
recording = sd.rec(int(duration * freq), 
                   samplerate=freq, channels=1)
  
sd.wait()
    
wv.write("recording.wav", recording, freq, sampwidth=2)

sound = AudioSegment.from_wav('recording.wav')

sound.export('myfile.mp3', format='mp3')
sound = AudioSegment.from_wav('recording.wav')
 
sound.export('recording.mp3', format='mp3')
# Out:
# <_io.BufferedRandom name='recording.mp3'>

# %%
def feature_out(predict_path):
    n_mfccs = 20 
    number_of_features = 3 + n_mfccs
    features = np.empty((0,number_of_features))
    mfccs, rmse, spectral_flux, zcr = feature_extraction(predict_path)
    extracted_features = np.hstack([mfccs, rmse, spectral_flux, zcr])
    features_predict = np.vstack([features, extracted_features])
    return features_predict

# %%
predict_path = 'recording.wav'
features_predict = feature_out(predict_path)
result = model_test.predict(features_predict)

# %%
result[0]
# Out:
# array([0., 1., 0.], dtype=float32)

# %%
i = np.argmax(result[0])
if(i==0):
    print('LOW')
elif(i==1):
    print('INTERMEDIATE')
else:
    print('HIGH')
# Out:
# INTERMEDIATE
